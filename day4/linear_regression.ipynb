# %%
# Importing the Required Modules 
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
# reading data from csv
data_url = "https://raw.githubusercontent.com/redashu/Datasets/refs/heads/master/advertising.csv"
df = pd.read_csv(data_url)

# %%
# checking metadata using pandas 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
# print top  5 rows
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
# selecting features and labels 
labels = df['Sales']
features = df[['TV','Radio','Newspaper']]
#print(features)

# %%
# spliting features and labels into training and testing data 90% , 10% 
# test_size == 0.0 to 1.0  0.1 -- 10% , 0.2 -- 20% 
feature_90,feature_10,label_90,label_10=train_test_split(features,labels,test_size=0.1)

# %%
# selecting Linear Regression 
model = LinearRegression()

# %%
# training model with 90% data of features and labels 
trained_model = model.fit(feature_90,label_90)

# %%
# Eval or testing 
predicted_output = trained_model.predict(feature_10)
print(predicted_output)
# Out:
# [20.86774797 18.31879251 10.30871652 20.16099029  8.9118412  22.12216898
#  19.2692161  15.4061168  14.94593687 19.30302405 23.73707612  9.34109523
#   6.29449783  9.35361751 18.97678876  9.05070293 13.73415452 16.00014791
#  21.10113508 18.62791745]

# %%
# actual answers as well
print(label_10)
# Out:
# 52     22.6
# 81     17.3
# 2      12.0
# 178    16.8
# 117     9.4
# 47     23.2
# 59     18.4
# 118    15.9
# 123    15.2
# 139    20.7
# 30     21.4
# 24      9.7
# 76      6.9
# 65     11.3
# 23     20.5
# 126     6.6
# 114    14.6
# 50     16.4
# 35     17.8
# 146    18.2
# Name: Sales, dtype: float64

# %%
# Creating graphs of datasets with features and labels 
plt.xlabel("TV advertise budget")
plt.ylabel("Sales")
plt.title("TV vs Sales graph")
plt.scatter(df['TV'],df['Sales'])
plt.show()

# %%
# Creating graphs of datasets with features and labels 
plt.xlabel("Radio advertise budget")
plt.ylabel("Sales")
plt.title("Radio vs Sales graph")
plt.scatter(df['Radio'],df['Sales'])
plt.show()

# %%
# Creating graphs of datasets with features and labels 
plt.xlabel("Newspaper advertise budget")
plt.ylabel("Sales")
plt.title("Newspaer vs Sales graph")
plt.scatter(df['Newspaper'],df['Sales'])
plt.show()

# %%
# importing modules
from dask.distributed import Client

# %%
# connecting to dask existing cluster
# Backend API url of scheduler machine 
cluster_url = "tcp://172.31.31.30:8786"
ashu_connect = Client(cluster_url)

# %%
# checking dashboard URL 
ashu_connect.dashboard_link
# Out:
# 'http://172.31.31.30:8787/status'

# %%
# checking some more details about cluster 
ashu_connect.scheduler_info()
# Out:
# {'type': 'Scheduler',
#  'id': 'Scheduler-7e4a1d70-2c48-4ba0-9b02-d2eb112f51ce',
#  'address': 'tcp://172.31.31.30:8786',
#  'services': {'dashboard': 8787},
#  'started': 1742323145.154169,
#  'workers': {'tcp://172.31.16.30:36757': {'type': 'Worker',
#    'id': 'tcp://172.31.16.30:36757',
#    'host': '172.31.16.30',
#    'resources': {},
#    'local_directory': '/tmp/dask-scratch-space/worker-d36_jdku',
#    'name': 'tcp://172.31.16.30:36757',
#    'nthreads': 2,
#    'memory_limit': 4102238208,
#    'last_seen': 1742329829.3120055,
#    'services': {'dashboard': 39459},
#    'metrics': {'task_counts': {},
#     'bandwidth': {'total': 100000000, 'workers': {}, 'types': {}},
#     'digests_total_since_heartbeat': {'latency': 0.0014791488647460938,
#      'tick-duration': 1.000467300415039},
#     'managed_bytes': 0,
#     'spilled_bytes': {'memory': 0, 'disk': 0},
#     'transfer': {'incoming_bytes': 0,
#      'incoming_count': 0,
#      'incoming_count_total': 0,
# ...

# %%
# checking more details
ashu_connect.scheduler_info().keys()
# Out:
# dict_keys(['type', 'id', 'address', 'services', 'started', 'workers'])

# %%
# printing only workers details
ashu_connect.scheduler_info()['workers'].keys()
# Out:
# dict_keys(['tcp://172.31.16.30:36757', 'tcp://172.31.16.49:38563', 'tcp://172.31.17.98:43081', 'tcp://172.31.20.251:42589', 'tcp://172.31.23.47:36245', 'tcp://172.31.24.229:38247', 'tcp://172.31.24.249:34031', 'tcp://172.31.26.132:35229', 'tcp://172.31.28.27:33023', 'tcp://172.31.29.214:40137', 'tcp://172.31.31.178:33661'])
